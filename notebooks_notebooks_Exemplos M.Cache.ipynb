# %% [markdown]
# ___
# # <center> Exemplo 5.2

# %%
from PIL import Image 
Image.open("E5.2.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=397x504>

# %% [markdown]
# #### <center>

# %% [markdown]
# #### <center> Demonstração do armazenamento de um programa na MP, para a utilização do processador
# #### <center> O programa é armazenado em diversas partes e requisitado, geralmente de forma sequencial, comportamento esse ao qual irá se basear o princípio da localidade
# #### <center> No exemplo, estão sendo demonstradas algumas funções, como os loops, os quais "chamam" novamente a sub-rotina 1 e, após essa execução, passam a executar as seguintes partes

# %% [markdown]
# ___
# # <center> Exemplo 5.3

# %%
Image.open("E5.3.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=568x662>

# %% [markdown]
# #### <center> Demonstração de um programa que está armazenado na MP e como ele seria divido em partes
# #### <center> Por exemplo, a primeira parte do programa define valores que serão utilizados e pede a quantidade de alunos a terem as notas verificadas, ou seja, quantas vezes o input responsável por armazenar as notas será repetido pelo loop
# #### <center> O programa irá executar o loop, registrando as notas de acordo com a matrícula e armazenando a maior nota da turma
# #### <center> Em seguida, o segundo loop irá ocorrer, repetindo o processo com os alunos de outra turma
# #### <center> Após o fim do loop de execução, ele irá limpar a tela do usuário e prosseguir com a próxima parte do programa
# #### <center> Ao final, ele irá exibir as informações que foram registradas durante a sua execução, de acordo com a análise

# %% [markdown]
# #### <center>

# %% [markdown]
# ___
# # <center> Exemplo 5.4

# %%
Image.open("E5.4.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=394x256>

# %% [markdown]
# #### <center>

# %% [markdown]
# #### <center> Demonstração do método de transferência de dados entre processador, cache e mp
# #### <center> A cache organiza a MP em blocos e os transfere para determinada linha, de acordo com o método de organização de blocos no armazenamento interno e de acordo com o endereço fornecido pelo processador.
# #### <center> Caso o bloco transferido seja o correto, a controladora irá identificar na linha a célula requisitada e transferir os dados para o processador
# #### <center> Vale lembrar que a célula não é equivalente ao tamanho da palavra, ou seja, mais de uma célula poderá ser transportada por vez via barramento de dados, dependendo da sua capacidade
#
# #### <center> OBS: A figura relata na segunda legenda "transferência cache/processador", quando na verdade deveria ser "transferência cache/mp"

# %% [markdown]
# ___
# # <center> Exemplo 5.5

# %%
Image.open("E5.5.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=453x272>

# %% [markdown]
# #### <center> Representação do funcionamento e das interligações que os barramentos realizam no sistema
# #### <center> O BE comunica-se tanto com a memória cache quanto com a memória principal, sendo suas respectivas controladoras responsáveis por decodificar o endereço fornecido pelo processador, por isso sua direção única
# #### <center> O barramento de controle irá transportar instruções entre os sistemas, como a operação de escrita e de controle, este sendo bidirecional pois a cache e a MP podem enviar instruções para o processador também
# #### <center> O barramento de dados irá transportar as palavras requisitadas para escrita e leitura, da cache para o processador, além de transportar o bloco que será armazenado temporariamente na linha, também atuando de forma bidirecional

# %% [markdown]
# ___
# # <center> Exemplo 5.6

# %%
Image.open("E5.6.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=503x295>

# %% [markdown]
# #### <center>

# %% [markdown]
# #### <center> Representação do funcionamento da organização por linhas dentro da memória cache
# #### <center> Cada cache possui um número determinado de linhas, representado de L0(Linha 0) até L-1
# #### <center> Por exemplo, uma cache com 8 linhas, será representada da linha 0 até a linha 7
# #### <center> Cada linha pode armazenar um bloco por vez, e sua largura é igual ao tamanho do bloco, ou seja, como o boco do exemplo armazena quatro células, cada linha também é capaz de armazenar quatro células

# %% [markdown]
# ___
# # <center> Exemplo 5.7

# %%
Image.open("E5.7.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=744x327>

# %% [markdown]
# #### <center>

# %% [markdown]
# #### <center> Demonstração do funcionamento da orgnização de blocos dentro da MP
# #### <center> Os blocos organizam-se de do bloco 0 até o bloco n - 1, ou seja, em ma MP com 32 blocos, eles iriam do bloco 0 até o bloco 31
# #### <center> Nesse exemplo, cada bloco comporta quatro células, assim como a largura da linha
# #### <center> Tais células organizam-se assim como os blocos, então de um total de células 64, elas iriam desde a célula0 até a célula 63
# #### <center> Por exemplo, para uma memória de 32 células (utilizando-se da convenção de que 1 byte = 1 célula) e com blocos de tamanho igual ao do exemplo (quatro células), a MP teria um total de 8 blocos, ou seja, iria do bloco 0 até o bloco 7

# %% [markdown]
# ___
# # <center> Exemplo 5.8

# %%
Image.open("E5.8.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=577x173>

# %% [markdown]
# #### <center> Nessa imagem, está representado um sistema de barramento único, ou seja, dados, endereços e instruções são transportados pelo mesmo canal de comunicação
# #### <center> Por exemplo, o processador pode enviar determinada instrução para a cache, que irá retornar determinada palavra, ambos os dados percorrendo o barramento único

# %% [markdown]
# ___
# # <center> Exemplo 5.9

# %%
Image.open("E5.9.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=664x695>

# %% [markdown]
# #### <center> Uma representação detalhada do mapeamento direto
# #### <center> O método de mapeamento direto irá designar que determinado bloco só poderá ser alocado em determinada linha da memoria cache, cada linha comportando determinada quantidade de blocos designados
# #### <center> A exemplo da linha 0, a qual estão determinados os blocos 0, 4, 8 e 12
# #### <center> Com esse exemplo também é possível comprovar que: Tamanho do bloco = Tamanho da célula, pois cada bloco comporta quatro células, assim como a linha
# #### <center> Também é possível observar que: Quantidade de Blocos > Quantidade de linhas, pois esse sistema possui 16 blocos e 4 linhas

# %% [markdown]
# ___
# # <center> Exemplo 5.10

# %%
Image.open("5.10.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=673x566>

# %% [markdown]
# #### <center> Na imagem acima, está sendo representado o método de mapeamento direto dos blocos presentes na MP para a memória cache
# #### <center> No método de mapeamento direto, um determinado número de blocos da MP são designados para determinada linha da memória cache, como no demonstrado para a linha 0, a qual comporta os blocos 0000, 0100, 1000 e 1100
# #### <center> Também é possível observar a demonstração da capacidade de armazenamento do bloco e da linha, a exemplo do bloco 0000, que comporta duas células, assim como a linha a qual ele pertence, que também comporta duas células, comprovando que: Tamanho da célula = Tamanho da linha
# #### <center> Por fim, é demonstrado a interpretação do endereço de 5 bits, o qual é interpretado por seções de bits
# #### <center> 2 bits para a identificação do bloco, pois cada linha pode receber quadro blocos (os mais significativos)
# #### <center> 2 bits para a identificação da linha, pois essa cache comporta 4 linhas em seu armazenamento
# #### <center> 1 bit para a identificação da célula, pois cada bloco comporta 2
